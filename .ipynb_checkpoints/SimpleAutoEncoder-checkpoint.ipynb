# %%
from keras.layers import Input, Dense
from keras.models import Model
from keras.datasets import mnist
import numpy as np
import matplotlib.pyplot as plt
from keras import regularizers
# Out:
# Using TensorFlow backend.

# %%
input_img = Input(shape = (784,))

# %%
#, activity_regularizer = regularizers.l1(10e-5)
X = Dense(128, activation = 'relu')(input_img)
X = Dense(64, activation = 'relu')(X)
X = Dense(32, activation = 'relu')(X)
X = Dense(64, activation = 'relu')(X)
X = Dense(128, activation = 'relu')(X)
X = Dense(784, activation = 'sigmoid')(X)

# %%
autoencoder = Model(input_img, X)
autoencoder.compile(optimizer = 'adam', loss = 'binary_crossentropy')

# %%
(x_train, _), (x_test, _) = mnist.load_data()

# %%
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255
# if we dont compute it as float32, then all values may reduce to 0 (if considered int)
print(x_train.shape)
print(x_test.shape)
# Out:
# (60000, 28, 28)
# (10000, 28, 28)

# %%
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))
print(x_train.shape)
print(x_test.shape)
# Out:
# (60000, 784)
# (10000, 784)

# %%
autoencoder.fit(x_train, x_train,
                epochs = 100,
                batch_size = 256,
                shuffle = True,
                validation_data = (x_test, x_test))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/100
# 60000/60000 [==============================] - 6s 107us/step - loss: 0.2453 - val_loss: 0.1665
# Epoch 2/100
# 60000/60000 [==============================] - 4s 73us/step - loss: 0.1513 - val_loss: 0.1362
# Epoch 3/100
# 60000/60000 [==============================] - 4s 74us/step - loss: 0.1312 - val_loss: 0.1243
# Epoch 4/100
# 60000/60000 [==============================] - 4s 73us/step - loss: 0.1218 - val_loss: 0.1169
# Epoch 5/100
# 60000/60000 [==============================] - 4s 73us/step - loss: 0.1162 - val_loss: 0.1126
# Epoch 6/100
# 60000/60000 [==============================] - 4s 73us/step - loss: 0.1122 - val_loss: 0.1088
# Epoch 7/100
# 60000/60000 [==============================] - 4s 73us/step - loss: 0.1090 - val_loss: 0.1066
# Epoch 8/100
# 60000/60000 [==============================] - 4s 73us/step - loss: 0.1067 - val_loss: 0.1044
# Epoch 9/100
# 60000/60000 [==============================] - 4s 73us/step - loss: 0.1047 - val_loss: 0.1026
# Epoch 10/100
# 60000/60000 [==============================] - 4s 74us/step - loss: 0.1031 - val_loss: 0.1016
# Epoch 11/100
# 60000/60000 [==============================] - 4s 74us/step - loss: 0.1016 - val_loss: 0.1002
# Epoch 12/100
# 60000/60000 [==============================] - 4s 73us/step - loss: 0.1004 - val_loss: 0.0987
# Epoch 13/100
# 60000/60000 [==============================] - 4s 74us/step - loss: 0.0993 - val_loss: 0.0978
# Epoch 14/100
# 60000/60000 [==============================] - 4s 73us/step - loss: 0.0983 - val_loss: 0.0967
# Epoch 15/100
# 60000/60000 [==============================] - 4s 73us/step - loss: 0.0973 - val_loss: 0.0958
# Epoch 16/100
# 60000/60000 [==============================] - 4s 73us/step - loss: 0.0963 - val_loss: 0.0947
# Epoch 17/100
# 60000/60000 [==============================] - 4s 73us/step - loss: 0.0954 - val_loss: 0.0941
# Epoch 18/100
# 60000/60000 [==============================] - 4s 75us/step - loss: 0.0946 - val_loss: 0.0935
# Epoch 19/100
# 60000/60000 [==============================] - 4s 74us/step - loss: 0.0938 - val_loss: 0.0931
# Epoch 20/100
# 60000/60000 [==============================] - 5s 76us/step - loss: 0.0931 - val_loss: 0.0920
# Epoch 21/100
# 60000/60000 [==============================] - 4s 74us/step - loss: 0.0925 - val_loss: 0.0918
# Epoch 22/100
# 60000/60000 [==============================] - 4s 74us/step - loss: 0.0919 - val_loss: 0.0908
# Epoch 23/100
# 60000/60000 [==============================] - 4s 75us/step - loss: 0.0913 - val_loss: 0.0902
# Epoch 24/100
# 60000/60000 [==============================] - 4s 74us/step - loss: 0.0908 - val_loss: 0.0899
# Epoch 25/100
# 60000/60000 [==============================] - 4s 74us/step - loss: 0.0904 - val_loss: 0.0896
# Epoch 26/100
# 60000/60000 [==============================] - 4s 74us/step - loss: 0.0899 - val_loss: 0.0891
# Epoch 27/100
# 60000/60000 [==============================] - 5s 79us/step - loss: 0.0896 - val_loss: 0.0887
# Epoch 28/100
# 60000/60000 [==============================] - 4s 74us/step - loss: 0.0893 - val_loss: 0.0885
# Epoch 29/100
# 60000/60000 [==============================] - 5s 76us/step - loss: 0.0889 - val_loss: 0.0881
# Epoch 30/100
# 60000/60000 [==============================] - 4s 74us/step - loss: 0.0886 - val_loss: 0.0879
# Epoch 31/100
# 60000/60000 [==============================] - 4s 75us/step - loss: 0.0883 - val_loss: 0.0881
# Epoch 32/100
# 60000/60000 [==============================] - 4s 74us/step - loss: 0.0881 - val_loss: 0.0874
# Epoch 33/100
# 60000/60000 [==============================] - 4s 74us/step - loss: 0.0877 - val_loss: 0.0871
# Epoch 34/100
# 60000/60000 [==============================] - 4s 73us/step - loss: 0.0875 - val_loss: 0.0869
# Epoch 35/100
#  - ETA: 0s - loss: 0.0873
# Epoch 36/100
# 60000/60000 [==============================] - 4s 74us/step - loss: 0.0870 - val_loss: 0.0866
# Epoch 37/100
# 60000/60000 [==============================] - 4s 74us/step - loss: 0.0867 - val_loss: 0.0860
# Epoch 38/100
# 60000/60000 [==============================] - 4s 74us/step - loss: 0.0865 - val_loss: 0.0860
# Epoch 39/100
# 60000/60000 [==============================] - 4s 74us/step - loss: 0.0864 - val_loss: 0.0857
# Epoch 40/100
# 60000/60000 [==============================] - 4s 74us/step - loss: 0.0861 - val_loss: 0.0856
# Epoch 41/100
# 60000/60000 [==============================] - 4s 74us/step - loss: 0.0860 - val_loss: 0.0854
# Epoch 42/100
# 60000/60000 [==============================] - 4s 74us/step - loss: 0.0858 - val_loss: 0.0855
# Epoch 43/100
# 60000/60000 [==============================] - 4s 74us/step - loss: 0.0856 - val_loss: 0.0850
# Epoch 44/100
# 60000/60000 [==============================] - 4s 74us/step - loss: 0.0854 - val_loss: 0.0849
# Epoch 45/100
# 60000/60000 [==============================] - 4s 74us/step - loss: 0.0853 - val_loss: 0.0847
# Epoch 46/100
# 60000/60000 [==============================] - 4s 74us/step - loss: 0.0852 - val_loss: 0.0846
# Epoch 47/100
# 60000/60000 [==============================] - 4s 74us/step - loss: 0.0850 - val_loss: 0.0847
# Epoch 48/100
# 60000/60000 [==============================] - 4s 75us/step - loss: 0.0849 - val_loss: 0.0843
# Epoch 49/100
# 60000/60000 [==============================] - 4s 74us/step - loss: 0.0847 - val_loss: 0.0843
# Epoch 50/100
# 60000/60000 [==============================] - 4s 74us/step - loss: 0.0845 - val_loss: 0.0841
# Epoch 51/100
# 60000/60000 [==============================] - 4s 74us/step - loss: 0.0844 - val_loss: 0.0837
# Epoch 52/100
# 60000/60000 [==============================] - 4s 74us/step - loss: 0.0842 - val_loss: 0.0838
# Epoch 53/100
# 60000/60000 [==============================] - 4s 74us/step - loss: 0.0840 - val_loss: 0.0835
# Epoch 54/100
# 60000/60000 [==============================] - 4s 74us/step - loss: 0.0839 - val_loss: 0.0835
# Epoch 55/100
# 60000/60000 [==============================] - 4s 74us/step - loss: 0.0838 - val_loss: 0.0833
# Epoch 56/100
# 60000/60000 [==============================] - 4s 74us/step - loss: 0.0836 - val_loss: 0.0833
# Epoch 57/100
# 60000/60000 [==============================] - 4s 73us/step - loss: 0.0835 - val_loss: 0.0831
# Epoch 58/100
# 60000/60000 [==============================] - 4s 74us/step - loss: 0.0834 - val_loss: 0.0828
# Epoch 59/100
# 60000/60000 [==============================] - 4s 73us/step - loss: 0.0832 - val_loss: 0.0829
# Epoch 60/100
# 60000/60000 [==============================] - 4s 74us/step - loss: 0.0832 - val_loss: 0.0827
# Epoch 61/100
# 60000/60000 [==============================] - 4s 73us/step - loss: 0.0831 - val_loss: 0.0825
# Epoch 62/100
# 60000/60000 [==============================] - 4s 74us/step - loss: 0.0830 - val_loss: 0.0826
# Epoch 63/100
# 60000/60000 [==============================] - 5s 77us/step - loss: 0.0829 - val_loss: 0.0825
# Epoch 64/100
# 60000/60000 [==============================] - 5s 76us/step - loss: 0.0828 - val_loss: 0.0822
# Epoch 65/100
# 60000/60000 [==============================] - 5s 76us/step - loss: 0.0827 - val_loss: 0.0824
# Epoch 66/100
# 60000/60000 [==============================] - 4s 75us/step - loss: 0.0827 - val_loss: 0.0823
# Epoch 67/100
# 60000/60000 [==============================] - 4s 75us/step - loss: 0.0826 - val_loss: 0.0826
# Epoch 68/100
# 60000/60000 [==============================] - 4s 74us/step - loss: 0.0825 - val_loss: 0.0822
# Epoch 69/100
# 60000/60000 [==============================] - 4s 74us/step - loss: 0.0824 - val_loss: 0.0820
# Epoch 70/100
# 60000/60000 [==============================] - 4s 74us/step - loss: 0.0824 - val_loss: 0.0820
# Epoch 71/100
# 60000/60000 [==============================] - 4s 74us/step - loss: 0.0823 - val_loss: 0.0820
# Epoch 72/100
# 60000/60000 [==============================] - 4s 74us/step - loss: 0.0822 - val_loss: 0.0819
# Epoch 73/100
# 60000/60000 [==============================] - 4s 74us/step - loss: 0.0822 - val_loss: 0.0819
# Epoch 74/100
# 60000/60000 [==============================] - 4s 74us/step - loss: 0.0821 - val_loss: 0.0817
# Epoch 75/100
# 60000/60000 [==============================] - 4s 74us/step - loss: 0.0821 - val_loss: 0.0819
# Epoch 76/100
# 60000/60000 [==============================] - 4s 74us/step - loss: 0.0820 - val_loss: 0.0818
# Epoch 77/100
# 60000/60000 [==============================] - 4s 74us/step - loss: 0.0820 - val_loss: 0.0815
# Epoch 78/100
# 60000/60000 [==============================] - 4s 74us/step - loss: 0.0819 - val_loss: 0.0817
# Epoch 79/100
# 60000/60000 [==============================] - 4s 74us/step - loss: 0.0819 - val_loss: 0.0817
# Epoch 80/100
# 60000/60000 [==============================] - 4s 74us/step - loss: 0.0819 - val_loss: 0.0818
# Epoch 81/100
# 60000/60000 [==============================] - 5s 81us/step - loss: 0.0818 - val_loss: 0.0818
# Epoch 82/100
# 60000/60000 [==============================] - 4s 74us/step - loss: 0.0818 - val_loss: 0.0815
# Epoch 83/100
# 60000/60000 [==============================] - 5s 75us/step - loss: 0.0817 - val_loss: 0.0817
# Epoch 84/100
# 60000/60000 [==============================] - 4s 74us/step - loss: 0.0817 - val_loss: 0.0812
# Epoch 85/100
# 60000/60000 [==============================] - 4s 74us/step - loss: 0.0816 - val_loss: 0.0816
# Epoch 86/100
# 60000/60000 [==============================] - 4s 74us/step - loss: 0.0816 - val_loss: 0.0812
# Epoch 87/100
# 60000/60000 [==============================] - 4s 74us/step - loss: 0.0815 - val_loss: 0.0812
# Epoch 88/100
# 60000/60000 [==============================] - 4s 74us/step - loss: 0.0816 - val_loss: 0.0812
# Epoch 89/100
# 60000/60000 [==============================] - 4s 74us/step - loss: 0.0815 - val_loss: 0.0812
# Epoch 90/100
# 60000/60000 [==============================] - 4s 74us/step - loss: 0.0815 - val_loss: 0.0813
# Epoch 91/100
# 60000/60000 [==============================] - 4s 74us/step - loss: 0.0814 - val_loss: 0.0811
# Epoch 92/100
# 60000/60000 [==============================] - 4s 74us/step - loss: 0.0814 - val_loss: 0.0813
# Epoch 93/100
# 60000/60000 [==============================] - 4s 74us/step - loss: 0.0814 - val_loss: 0.0810
# Epoch 94/100
# 60000/60000 [==============================] - 4s 74us/step - loss: 0.0813 - val_loss: 0.0809
# Epoch 95/100
# 60000/60000 [==============================] - 4s 74us/step - loss: 0.0813 - val_loss: 0.0811
# Epoch 96/100
# 60000/60000 [==============================] - 4s 75us/step - loss: 0.0813 - val_loss: 0.0809
# Epoch 97/100
# 60000/60000 [==============================] - 5s 75us/step - loss: 0.0813 - val_loss: 0.0811
# Epoch 98/100
# 60000/60000 [==============================] - 4s 74us/step - loss: 0.0812 - val_loss: 0.0810
# Epoch 99/100
# 60000/60000 [==============================] - 4s 74us/step - loss: 0.0812 - val_loss: 0.0813
# Epoch 100/100
# 60000/60000 [==============================] - 5s 76us/step - loss: 0.0812 - val_loss: 0.0810

# %%
decoded_imgs = autoencoder.predict(x_test)

# %%
n = 10
plt.figure(figsize=(20, 4))
for i in range(n):
    original = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28,28), cmap = 'gray')

    reconstructed = plt.subplot(2, n, n + i + 1)
    plt.imshow(decoded_imgs[i].reshape(28, 28), cmap = 'gray')
plt.show()
